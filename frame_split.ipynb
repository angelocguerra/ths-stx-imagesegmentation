# %%
import cv2
import os
def extract_frames(video_path, output_root, interval=5):
    """
    Extracts frames from a video every 'interval' seconds.

    :param video_path: Path to the input video file.
    :param output_root: Root directory where frames will be saved.
    :param interval: Time interval (in seconds) between frames.
    """
    video_name = os.path.splitext(os.path.basename(video_path))[0]
    output_folder = os.path.join(output_root, video_name)
    print("Checking if exist:", output_folder)

    # Check if the output folder already exists
    if os.path.exists(output_folder):
        print(f"Skipping {video_name}, frames already extracted.")
        return

    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    cap = cv2.VideoCapture(video_path)
    fps = int(cap.get(cv2.CAP_PROP_FPS))  # Get frames per second
    print(f"Processing {video_name} (FPS: {fps})")
    frame_interval = fps * interval  # Convert seconds to frame count

    frame_count = 0
    saved_count = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        if frame_count % frame_interval == 0:
            frame_filename = os.path.join(output_folder, f"frame_{saved_count:04d}.jpg")
            cv2.imwrite(frame_filename, frame)
            saved_count += 1

        frame_count += 1

    cap.release()
    print(f"Extracted {saved_count} frames to {output_folder}\n")

def process_all_videos(videos_directory, output_root, interval=5):
    """
    Iterates through all videos in the given directory and extracts frames.

    :param videos_directory: Directory containing video files.
    :param output_root: Root directory for saving extracted frames.
    :param interval: Time interval (in seconds) between frames.
    """
    if not os.path.exists(videos_directory):
        print(f"Directory '{videos_directory}' does not exist.")
        return

    video_files = [f for f in os.listdir(videos_directory) if f.lower().endswith((".mp4", ".avi", ".mov", ".mkv", ".webm"))]

    if not video_files:
        print("No video files found in the directory.")
        return

    for video_file in video_files:
        video_path = os.path.join(videos_directory, video_file)
        extract_frames(video_path, output_root, interval)

# %%
videos_directory = "downloads/videos/"
process_all_videos(videos_directory, output_root="output_frames/")
# Out:
# Checking if exist: output_frames/Chilly Wet Morning Ride Alert Level 1 Edsa Bike Lane POV Katipunan to Magallanes GoPro 9
# Skipping Chilly Wet Morning Ride Alert Level 1 Edsa Bike Lane POV Katipunan to Magallanes GoPro 9, frames already extracted.
# Checking if exist: output_frames/Bike Lane Ride - McKinley Road - EDSA to BGC - 2 km
# Skipping Bike Lane Ride - McKinley Road - EDSA to BGC - 2 km, frames already extracted.
# Checking if exist: output_frames/Bike Lane Ride - C6 Bike Lane After Raining
# Skipping Bike Lane Ride - C6 Bike Lane After Raining, frames already extracted.
# Checking if exist: output_frames/Bike Lane Ride - Ortigas Ave. Eastbound - EDSA to C-5 - 2.42 km
# Skipping Bike Lane Ride - Ortigas Ave. Eastbound - EDSA to C-5 - 2.42 km, frames already extracted.
# Checking if exist: output_frames/Bike Lane Ride - EDSA Northbound - Magallanes to Ortigas Ave. - 7.40 km
# Processing Bike Lane Ride - EDSA Northbound - Magallanes to Ortigas Ave. - 7.40 km (FPS: 59)
# Extracted 304 frames to output_frames/Bike Lane Ride - EDSA Northbound - Magallanes to Ortigas Ave. - 7.40 km
#
# Checking if exist: output_frames/C5 Libis to Ortigas Avenue (southbound) - DPWH bike lane
# Skipping C5 Libis to Ortigas Avenue (southbound) - DPWH bike lane, frames already extracted.
# Checking if exist: output_frames/My First Bicycle Ride in Manila, Philippines
# Skipping My First Bicycle Ride in Manila, Philippines, frames already extracted.
# Checking if exist: output_frames/Bike Lane Ride - C5 Southbound - C5-Ortigas to Market Market - 5.40 km
# Skipping Bike Lane Ride - C5 Southbound - C5-Ortigas to Market Market - 5.40 km, frames already extracted.
# Checking if exist: output_frames/One Shot Bike Ride - East bound on Ayala Ave. and McKinley Road - 4.20 km
# Skipping One Shot Bike Ride - East bound on Ayala Ave. and McKinley Road - 4.20 km, frames already extracted.
# Checking if exist: output_frames/Makati To Tagaytay & Back ｜MTB 119km Solo Bicycle Ride
# Skipping Makati To Tagaytay & Back ｜MTB 119km Solo Bicycle Ride, frames already extracted.
# Checking if exist: output_frames/CHILL MTB RIDE ｜ Roxas Boulevard Manila
# Skipping CHILL MTB RIDE ｜ Roxas Boulevard Manila, frames already extracted.
